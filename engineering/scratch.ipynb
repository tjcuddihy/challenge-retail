# %% [markdown]
# # Scratch pad
#
# Hi, this is where I mess around with ideas outside of the report notebook. Once it works and is worth including, I transfer the logic back to the report notebook.
#
# Feel free to look through here but keep in mind that it's a stream of conciousness and not intended to be run in the future.

# %%
# !python --version
# !pip list
# Out:
# Python 3.9.0
# Package             Version
# ------------------- ---------
# appnope             0.1.0
# argon2-cffi         20.1.0
# async-generator     1.10
# attrs               20.3.0
# backcall            0.2.0
# bleach              3.2.1
# certifi             2020.11.8
# cffi                1.14.3
# chardet             3.0.4
# decorator           4.4.2
# defusedxml          0.6.0
# entrypoints         0.3
# idna                2.10
# ipykernel           5.3.4
# ipython             7.19.0
# ipython-genutils    0.2.0
# jedi                0.17.2
# Jinja2              2.11.2
# json5               0.9.5
# jsonschema          3.2.0
# jupyter-client      6.1.7
# jupyter-core        4.7.0
# jupyterlab          2.2.9
# jupyterlab-pygments 0.1.2
# jupyterlab-server   1.2.0
# MarkupSafe          1.1.1
# mistune             0.8.4
# nbclient            0.5.1
# nbconvert           6.0.7
# nbformat            5.0.8
# nest-asyncio        1.4.3
# notebook            6.1.5
# ...

# %%
import pandas as pd

# %%
raw_data = pd.read_csv('../data/01_raw/Retail.csv')

# %%
raw_data
# Out:
#        Year              Product line  Product type              Product  \
# 0      2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# 1      2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# 2      2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# 3      2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# 4      2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# ...     ...                       ...           ...                  ...
# 84667  2007  Mountaineering Equipment         Tools      Granite Extreme
# 84668  2007  Mountaineering Equipment         Tools      Granite Extreme
# 84669  2007  Mountaineering Equipment         Tools      Granite Extreme
# 84670  2007  Mountaineering Equipment         Tools      Granite Extreme
# 84671  2007  Mountaineering Equipment         Tools      Granite Extreme
#
#       Order method type Retailer country    Revenue  Planned revenue  \
# ...

# %%
sales_performance = raw_data[['Year', 'Product', 'Order method type', 'Retailer country', 'Revenue', 'Quantity', 'Gross profit']].dropna()

# %%
import plotly.express as px

# %%
figure=px.bar(df_yearly_performance,
              x="Year",
              y="value",
              color="variable",
              barmode="group",
              labels={"value": "$"},
              color_discrete_sequence=[
                  "#519872",
                  "#34252f",
              ],
             ),b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-c7ff2edfd66d> in <module>
#       1 figure=px.bar(
# ----> 2                                             df_yearly_performance,
#       3                                             x="Year",
#       4                                             y="value",
#       5                                             color="variable",
#
# NameError: name 'df_yearly_performance' is not defined

# %%
sales_performance
# Out:
#        Year              Product Order method type Retailer country  \
# 0      2004  TrailChef Water Bag         Telephone    United States
# 1      2004  TrailChef Water Bag         Telephone           Canada
# 4      2004  TrailChef Water Bag         Telephone            Japan
# 6      2004  TrailChef Water Bag         Telephone            China
# 7      2004  TrailChef Water Bag         Telephone        Singapore
# ...     ...                  ...               ...              ...
# 84585  2007      Granite Extreme               Web          Austria
# 84586  2007      Granite Extreme               Web            Italy
# 84587  2007      Granite Extreme               Web            Spain
# 84595  2007      Granite Extreme           Special        Singapore
# 84631  2007      Granite Extreme            E-mail           Canada
#
#          Revenue    Revenue  Gross profit
# 0      315044.33  315044.33     156672.57
# 1       13444.68   13444.68       7145.88
# ...

# %%
col_options = [dict(label=x, value=x) for x in ['Product', 'Order method type', 'Retailer country', 'Revenue', 'Quantity', 'Gross profit']]

# %%
col_options
# Out:
# [{'label': 'Product', 'value': 'Product'},
#  {'label': 'Order method type', 'value': 'Order method type'},
#  {'label': 'Retailer country', 'value': 'Retailer country'},
#  {'label': 'Revenue', 'value': 'Revenue'},
#  {'label': 'Quantity', 'value': 'Quantity'},
#  {'label': 'Gross profit', 'value': 'Gross profit'}]

# %%
@app.callback(Output("graph", "figure"), [Input(d, "value") for d in dimensions])
def make_figure(x='Year', y, color, facet_col, facet_row):
    return px.scatter(
        tips,
        x=x,
        y=y,
        color=color,
        facet_col=facet_col,
        facet_row=facet_row,
        height=700,
    )
# Out:
#   File "<ipython-input-74-aaa3fa702140>", line 2
#     def make_figure(x='Year', y, color, facet_col, facet_row):
#                                  ^
# SyntaxError: non-default argument follows default argument

# %%
px.scatter(sales_performance, x='Year', y='Revenue')
